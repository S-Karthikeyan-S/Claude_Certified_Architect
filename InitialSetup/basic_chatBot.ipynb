# %%
from anthropic import Anthropic

try:
    client=Anthropic(
        base_url="http://localhost:8000",
        api_key="fake-key-for-sdk-validation"
    )
    print("Sending the request through the proxy server to Google Gemini API...")
except Exception as e:
    print("Error initializing the client:", str(e))
# Out:
# Sending the request through the proxy server to Google Gemini API...

# %%
#testing the connection: 
messages = client.messages.create(
    model="claude-3-5-sonnet-20241022",
    max_tokens=1000,
    messages=[{"role": "user", "content": "tell me a joke"}]
)

messages.content[0].text
# Out:
# "Here's one for you:\n\nWhy don't scientists trust atoms?\n\nBecause they make up everything!"

# %% [markdown]
# ACTUALL CHAT BOT CODE :

# %%
def add_user_message(messages,content):
    user_message={"role": "user", "content": content}
    messages.append(user_message)
    
def add_assistant_message(messages,content):
    assistant_message={"role": "assistant", "content": content}
    messages.append(assistant_message)
    
def chatBot(messages):
    responce = client.messages.create(
        model="claude-3-5-sonnet-20241022",
        max_tokens=1000,
        messages=messages
    )
    return responce.content[0].text

# %%
# def initiate_chat():
#     messages=[]
#     while True:
#         user_input=input("User: ")
#         add_user_message(messages,user_input)
#         if user_input.lower() in ["exit","quit"]:
#             print("Exiting the chat. Goodbye!")
#             break
#         assistant_response=chatBot(messages)
#         add_assistant_message(messages,assistant_response)
#         print("Assistant:",assistant_response)

# %%
def initiate_chat():
        messages=[]
        while True:
            user_input=input("User: ") 
            add_user_message(messages,user_input)
            if user_input.lower() in ["exit","quit"]:
                print("BYE!")
                break
            response=chatBot(messages)
            add_assistant_message(messages,response)
            print("Assistant:",response)

# %%
initiate_chat()
# Out:
# BYE!
